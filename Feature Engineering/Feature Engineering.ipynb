# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def create_ages(mu=50,sigma=13,nsamples=100,seed=42):
    np.random.seed(seed)
    sample_ages = np.random.normal(loc=mu,scale=sigma,size=nsamples)
    sample_ages = np.round(sample_ages,decimals=0)
    return sample_ages

# %%
sample = create_ages()

# %%
sample
# Out:
# array([56., 48., 58., 70., 47., 47., 71., 60., 44., 57., 44., 44., 53.,
#        25., 28., 43., 37., 54., 38., 32., 69., 47., 51., 31., 43., 51.,
#        35., 55., 42., 46., 42., 74., 50., 36., 61., 34., 53., 25., 33.,
#        53., 60., 52., 48., 46., 31., 41., 44., 64., 54., 27., 54., 45.,
#        41., 58., 63., 62., 39., 46., 54., 63., 44., 48., 36., 34., 61.,
#        68., 49., 63., 55., 42., 55., 70., 50., 70., 16., 61., 51., 46.,
#        51., 24., 47., 55., 69., 43., 39., 43., 62., 54., 43., 57., 51.,
#        63., 41., 46., 45., 31., 54., 53., 50., 47.])

# %%
sns.displot(sample)

# %%
sns.boxplot(data=sample) #small dot below is an outlier
# Out:
# <AxesSubplot: >

# %%
ser = pd.Series(sample)

# %%
ser.describe()
# Out:
# count    100.00000
# mean      48.66000
# std       11.82039
# min       16.00000
# 25%       42.00000
# 50%       48.00000
# 75%       55.25000
# max       74.00000
# dtype: float64

# %%
IQR = 55.25-42.0

# %%
lower_limit = 42.0-1.5*IQR

# %%
lower_limit # this is the minimum limit that we can have with the data
# Out:
# 22.125

# %%
q75,q25 = np.percentile(sample,[75,25])

# %%
q75
# Out:
# 55.25

# %%
q25
# Out:
# 42.0

# %%
df = pd.read_csv('AmesHousing.csv')

# %%
df.corr()
# Out:
# C:\Users\astro\AppData\Local\Temp\ipykernel_14496\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     Order       PID  MS SubClass  Lot Frontage  Lot Area  \
# Order            1.000000  0.173593     0.011797     -0.007034  0.031354
# PID              0.173593  1.000000    -0.001281     -0.096918  0.034868
# MS SubClass      0.011797 -0.001281     1.000000     -0.420135 -0.204613
# Lot Frontage    -0.007034 -0.096918    -0.420135      1.000000  0.491313
# Lot Area         0.031354  0.034868    -0.204613      0.491313  1.000000
# Overall Qual    -0.048500 -0.263147     0.039419      0.212042  0.097188
# Overall Cond    -0.011054  0.104451    -0.067349     -0.074448 -0.034759
# Year Built      -0.052319 -0.343388     0.036579      0.121562  0.023258
# ...

# %%
sns.scatterplot(x = 'Overall Qual',y = 'SalePrice',data=df)
# Out:
# <AxesSubplot: xlabel='Overall Qual', ylabel='SalePrice'>
