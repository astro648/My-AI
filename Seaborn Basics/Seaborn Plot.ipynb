# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dm_office_sales.csv')

# %%
df.head() # the beginning parts of the data
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
# figsize: change sizing of the plot
# dpi: changes resolution of the plot
plt.figure(figsize = (12,4),dpi=200)

# x, y show the values that will be used
# data is the source dataframe
# hue changes the color depending on the data provided
sns.scatterplot(x='salary',y='sales',data=df,hue='level of education')
# Out:
# <AxesSubplot: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize = (12,4),dpi=200)
sns.scatterplot(x='salary',y='sales',data=df,hue='salary') # different columns for hue cause different results
# Out:
# <AxesSubplot: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize = (12,4),dpi=200)
sns.scatterplot(x='salary',y='sales',data=df,hue='level of education',palette='Set1')
# Now it uses the Set1 color palette from the Qualitative Colormaps section https://matplotlib.org/stable/tutorials/colors/colormaps.html
# Out:
# <AxesSubplot: xlabel='salary', ylabel='sales'>

# %%
sns.rugplot(x='salary',data=df, height=0.5) # Basic rug plot
# Out:
# <AxesSubplot: xlabel='salary'>

# %%
sns.set(style = 'whitegrid') # this changes the style of the plot

sns.displot(data=df,x='salary',bins=20,color='red',edgecolor='blue',linewidth=1,ls='--') # this is a histogram
# bins will change the amount of bars
# if you set bins to 20, then there will be 20 bars
# ls changes the line style, current line style is dashed

# %%
sns.displot(data=df,x='salary',kde=True,rug=True) # this is also a histogram
# kdeplot is like a line plot

# %%
sns.kdeplot(data=df,x='salary') # now we have a line plot
# Out:
# <AxesSubplot: xlabel='salary', ylabel='Density'>

# %%
np.random.seed(42)
sample_ages = np.random.randint(0,100,200)

# %%
sample_ages = pd.DataFrame(sample_ages,columns=['age'])
sns.rugplot(data=sample_ages,x='age')
# Out:
# <AxesSubplot: xlabel='age'>

# %%
sns.displot(data=sample_ages,x='age',bins=30,kde=True,rug=True)

# %%
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.countplot(data=df,x='level of education',hue='division',palette='Set2')
# plt.ylim(90,260)
# Out:
# <AxesSubplot: xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.barplot(data=df,x='level of education',y='salary',hue='division',estimator=np.mean,errorbar='sd')
# Out:
# <AxesSubplot: xlabel='level of education', ylabel='salary'>

# %%
sp = pd.read_csv('StudentsPerformance.csv')
sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(data=sp,y='math score',x='parental level of education',hue='test preparation course',palette='Set1')
plt.legend(bbox_to_anchor=(1.05,1))

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.violinplot(data=sp,y='math score',x='parental level of education',hue='test preparation course',palette='Set1',split=True,inner=None)
plt.legend(bbox_to_anchor=(1.05,1))

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.swarmplot(data=sp,x='math score',y='gender',size=2,hue='test preparation course')
# Out:
# <AxesSubplot: xlabel='math score', ylabel='gender'>

# %%
sns.boxenplot(data=sp,x='math score',y='test preparation course',hue='gender')
# Out:
# <AxesSubplot: xlabel='math score', ylabel='test preparation course'>

# %%
sns.jointplot(data=sp,x='math score',y='reading score',kind='hex') #hex, hist, kde, scatterplot

# %%
sns.jointplot(data=sp,x='math score',y='reading score',fill=True,hue='gender',kind='hist')

# %%
sns.jointplot(data=sp,x='math score',y='reading score',hue='gender',kind='scatter')

# %%
sns.jointplot(data=sp,x='math score',y='reading score',fill=True,hue='gender',kind='kde')

# %%
sns.pairplot(data=sp,hue='gender',corner=True,diag_kind='hist')

# %%
pc = pd.read_csv('population_by_country_2020.csv')
pc.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
pc = pc.set_index('Country')
pc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22376\3215648425.py in <module>
# ----> 1 pc = pc.set_index('Country (or dependency)')
#       2 pc
#
# ~\anaconda3\envs\myai\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~\anaconda3\envs\myai\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5999
#    6000         if missing:
# -> 6001             raise KeyError(f"None of {missing} are in the columns")
#    6002
#    6003         if inplace:
#
# KeyError: "None of ['Country (or dependency)'] are in the columns"
