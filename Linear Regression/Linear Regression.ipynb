# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
addf = pd.read_csv('advertising.csv')

# %%
addf.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
addf['Total Spent'] = addf['TV'] + addf['Radio'] + addf['Newspaper']

# %%
sns.regplot(data=addf,x='Total Spent',y='Sales') # regression plot
# Out:
# <AxesSubplot: xlabel='Total Spent', ylabel='Sales'>

# %%
X = addf['Total Spent']
y = addf['Sales']
np.polyfit(X,y,deg=1)
# Out:
# array([0.0525585, 4.573573 ])

# %%
potentialSpent = np.linspace(0,500,100)

# %%
predictedSales = 0.0525585 * potentialSpent + 4.573573

# %%
sns.scatterplot(x='Total Spent',y='Sales',data=addf,color='red')
plt.plot(potentialSpent,predictedSales)

# %%
spend=200
predictedSales = 0.0525585 * spend + 4.573573

# %%
predictedSales
# Out:
# 15.085272999999999
